// %%
#include <dlfcn.h>
#include <iostream>

dlopen("CudaSourse/libcuda.so", RTLD_NOW | RTLD_GLOBAL);

// %%
extern "C" void add(int blocks, int threads, int a, int b, int *result);

// %%
int result = 0;
add(1, 1, 2, 3, &result);
std::cout << result << std::endl;
// Out:
// JIT session error: Symbols not found: [ add ]
// Failed to execute via ::process:Failed to materialize symbols: { (main, { result, __orc_init_func.incr_module_5, $.incr_module_5.__inits.0 }) }
// Error: Compilation error! JIT session error: Symbols not found: [ add ]
// Failed to execute via ::process:Failed to materialize symbols: { (main, { result, __orc_init_func.incr_module_5, $.incr_module_5.__inits.0 }) }

// %%
#include <iostream>
#include <cuda_runtime.h>

dlopen("CudaSourse/libcuda.so", RTLD_NOW | RTLD_GLOBAL);

// %%
extern "C" void vector_add(int N, int *a, int *b, int *c);

// %%
const int N = 10;
int a[N], b[N], c[N];

for (int i = 0; i < N; i++) {
    a[i] = -i;
    b[i] = i * i;
}

vector_add(N, a, b, c);

for (int i = 0; i < N; i++) {
    std::cout << a[i] << " + " << b[i] << " = " << c[i] << "\n";
}

// %%
extern "C" void run_julia(unsigned char *output);

// %%
#define STB_IMAGE_WRITE_IMPLEMENTATION
#include "stb_image_write.h"

unsigned char *bitmap = new unsigned char[DIM * DIM * 4];
run_julia(bitmap);
stbi_write_png("julia.png", DIM, DIM, 4, bitmap, DIM * 4);
std::cout << "Saved to julia.png" << std::endl;
delete[] bitmap;

// %%
#include <string>
#include <fstream>
#include <sstream>
#include "nlohmann/json.hpp"
#include "xeus/xbase64.hpp"

namespace nl = nlohmann;

namespace im
{
    struct image
    {
        inline image(const std::string& filename)
        {
            std::ifstream fin(filename, std::ios::binary);
            m_buffer << fin.rdbuf();
        }

        std::stringstream m_buffer;
    };

    nl::json mime_bundle_repr(const image& i)
    {
        auto bundle = nl::json::object();
        bundle["image/png"] = xeus::base64encode(i.m_buffer.str());
        return bundle;
    }
}

// %%
#include "xcpp/xdisplay.hpp"

im::image julia("julia.png");
xcpp::display(julia);
